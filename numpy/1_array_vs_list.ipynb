# %% [markdown]
# # Numpy array vs List
# - List can contain multiple data types, array contains only same type data
# - In mathematical operation, loop needed for list, But using array its simple

# %%
import numpy as np

x = [10, 20, 30, 40]

print(x * 2) # normal python list

numbers = np.array(x)

print(numbers)
print(numbers * 2)
# Out:
# [10, 20, 30, 40, 10, 20, 30, 40]
# [10 20 30 40]
# [20 40 60 80]
