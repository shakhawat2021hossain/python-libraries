# %%
import numpy as np

arr1 = np.array([1, 2, 3, 4, 5])
print(arr1)

arr1_sqrt = np.sqrt(arr1) # [1. 1.41421356 1.73205081 2. 2.23606798]

print("sqrt(rounded):", np.round(arr1_sqrt, 2))
print("sin:", np.sin(arr1))
print("exp:", np.exp(arr1))
# Out:
# [1 2 3 4 5]
# square [   1    4   27  256 3125]
# sqrt(rounded): [1.   1.41 1.73 2.   2.24]
# sin: [ 0.84147098  0.90929743  0.14112001 -0.7568025  -0.95892427]
# exp: [  2.71828183   7.3890561   20.08553692  54.59815003 148.4131591 ]
