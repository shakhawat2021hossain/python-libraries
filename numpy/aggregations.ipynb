# %%
import numpy as np

x = [1, 2, 3, 4, 5]

arr = np.array(x)

print(f" sum: {arr.sum()} \n max: {arr.max()} \n min: {arr.min()} \n mean: {arr.mean()} \n variance: {arr.var()} \n std deviation: {arr.std()}")
# Out:
#  sum: 15
#  max: 5
#  min: 1
#  mean: 3.0
#  variance: 2.0
#  std deviation: 1.4142135623730951
